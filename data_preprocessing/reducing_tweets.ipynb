# %% [markdown]
# #Getting started

# %%
# Getting started
# Importing required libraries for the project
import numpy as np # for scientific computing
import pandas as pd # for data anaysis
import matplotlib # for visualization
import seaborn as sns # for visualization
import gdown
import os
import math

# Set pandas display
pd.options.display.max_columns = 50
pd.options.display.max_rows = 20

from tqdm.auto import tqdm
tqdm.pandas()

# %%
# Import and link your google drive
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# To access it from your computer, you'll have to put the correct path
# All the hydrated tweets
tw = pd.read_csv("/content/drive/MyDrive/UCL/Y2/QM2/QM2/15m_hyd_tweets.csv")
print(tw.shape)
# Out:
# (12205281, 35)

# %%
tw.tail()
# Out:
#          coordinates                      created_at               hashtags  \
# 12205276         NaN  Sat Mar 14 14:33:02 +0000 2020                    NaN
# 12205277         NaN  Wed Jan 27 15:29:26 +0000 2021  Melbourne Transit PTV
# 12205278         NaN  Fri Mar 27 03:11:48 +0000 2020                    NaN
# 12205279         NaN  Fri Feb 05 18:32:11 +0000 2021     TransitIsEssential
# 12205280         NaN  Tue Mar 03 14:19:06 +0000 2020              SmartNews
#
#                                                       media  \
# 12205276                                                NaN
# 12205277                                                NaN
# 12205278  https://twitter.com/gail_biggins/status/124337...
# 12205279                                                NaN
# 12205280                                                NaN
#
#                                                        urls  favorite_count  \
# 12205276  https://twitter.com/QHaRi/status/1238247431801...               2
# 12205277  https://www.heraldsun.com.au/coronavirus/15min...               0
# 12205278                                                NaN               0
# 12205279                                                NaN               1
# 12205280  https://www.businessinsider.com/trump-administ...               0
#
#                            id in_reply_to_screen_name  in_reply_to_status_id  \
# 12205276  1238835534916698118                     NaN                    NaN
# 12205277  1354451459081965577                     NaN                    NaN
# 12205278  1243375138629767168              FBIMiamiFL                    NaN
# 12205279  1357758940390555649                     NaN                    NaN
# 12205280  1234845760182726656                     NaN                    NaN
#
#           in_reply_to_user_id lang place possibly_sensitive      quote_id  \
# 12205276                  NaN   en   NaN              False  1.238247e+18
# 12205277                  NaN   en   NaN              False           NaN
# 12205278          347505959.0   en   NaN              False           NaN
# 12205279                  NaN   en   NaN                NaN           NaN
# 12205280                  NaN   en   NaN              False           NaN
#
#           retweet_count  retweet_id retweet_screen_name  \
# 12205276              0         NaN                 NaN
# 12205277              0         NaN                 NaN
# 12205278              0         NaN                 NaN
# 12205279              1         NaN                 NaN
# 12205280              0         NaN                 NaN
#
#                                                      source  \
# 12205276  <a href="http://twitter.com/download/iphone" r...
# 12205277  <a href="https://ifttt.com" rel="nofollow">IFT...
# 12205278  <a href="http://twitter.com/download/android" ...
# 12205279  <a href="https://mobile.twitter.com" rel="nofo...
# 12205280  <a href="http://twitter.com/download/iphone" r...
#
#                                                        text  \
# 12205276                read nibbas https://t.co/ZopkCsoiMi
# 12205277  Coronavirus: 15-minute immunity test could be ...
# 12205278  @FBIMiamiFL @DeptofDefense Well Dallas .... Te...
# 12205279  .@RepPeterDeFazio, @RepSamGraves, @SenSherrodB...
# 12205280  The Trump administration says Medicare and Med...
#
#                                                   tweet_url  \
# 12205276  https://twitter.com/___Ivxn/status/12388355349...
# 12205277  https://twitter.com/MyTransit_MEL/status/13544...
# 12205278  https://twitter.com/gail_biggins/status/124337...
# 12205279  https://twitter.com/ldellapiana/status/1357758...
# 12205280  https://twitter.com/Cathode2/status/1234845760...
#
#                          user_created_at              user_id  \
# 12205276  Mon Apr 18 23:26:06 +0000 2016   722204589361995776
# 12205277  Tue Oct 29 06:08:36 +0000 2019  1189061368646950912
# 12205278  Sun Apr 07 02:23:02 +0000 2019  1114715173275615233
# 12205279  Fri Sep 05 21:39:40 +0000 2008             16149944
# 12205280  Wed Aug 03 17:31:53 +0000 2011            347974196
#
#           user_default_profile_image  \
# 12205276                       False
# 12205277                       False
# 12205278                       False
# 12205279                       False
# 12205280                        True
#
#                                            user_description  \
# 12205276                                                NaN
# 12205277  Latest Melbourne #Transportation news covering...
# 12205278                                                  X
# 12205279  Mvmt strategist, educator & writer. @ForAJustS...
# 12205280                                                NaN
#
#           user_favourites_count  user_followers_count  user_friends_count  \
# 12205276                   1057                   509                 302
# 12205277                     78                    80                 175
# 12205278                   1643                    47                 193
# 12205279                   6204                  2283                3217
# 12205280                     23                     1                  13
#
#           user_listed_count         user_location            user_name  \
# 12205276                  0                   NaN                 Iván
# 12205277                  2  Melbourne, Australia  MyTransit Melbourne
# 12205278                  0                   NaN              BIGGSX3
# 12205279                 97         New York City   Libero Della Piana
# 12205280                  0                   NaN           Carl Jones
#
#          user_screen_name  user_statuses_count  user_time_zone  \
# 12205276          ___Ivxn                 1998             NaN
# 12205277    MyTransit_MEL                 7537             NaN
# 12205278     gail_biggins                17378             NaN
# 12205279      ldellapiana                12090             NaN
# 12205280         Cathode2                 4835             NaN
#
#                                   user_urls  user_verified
# 12205276                                NaN          False
# 12205277                                NaN          False
# 12205278                                NaN          False
# 12205279  https://www.liberodellapiana.com/          False
# 12205280                                NaN          False

# %% [markdown]
# #Getting the data ready for analysis

# %% [markdown]
# > Getting to the essential

# %%
# Only keep the relevant information ["id", "user_location","created_at"] and only keep the row that have location.
tw = tw[["id", "user_location", "created_at"]]
tw.dropna(subset=["user_location"], inplace=True)
print(tw.shape)
# Out:
# (8947664, 3)

# %% [markdown]
# > Formalizing dates

# %%
# Formalize dates to 'Month Year'
import datetime
tw["created_at"] = tw["created_at"].apply(lambda x: datetime.datetime.strptime(x, "%a %b %d %H:%M:%S %z %Y").strftime("%b %Y"))

# %% [markdown]
# #BERT label

# %%
bert = pd.read_csv("/content/drive/MyDrive/UCL/Y2/QM2/QM2/asonam_release_all_tweets.csv")
print(bert.shape)
# Out:
# (206348565, 2)

# %%
bert = bert.rename(columns={"Tweet ID": "id"})

# %%
twbert = pd.merge(tw, bert, on='id', how='left')

# %% [markdown]
# The BERT label can be equal to 0 which corrrespond to neutral speech, or equal to 1 which correspond to counter speech or "anti-hate speech", or equal to 2 which correspond to hate speech. It is because we took our data from a paper that has interest in the effect of counter speech, however, we do not. Let's get rid of this notation.

# %%
def change_bert(label):
    if label == 0:
        return label
    elif label == 1:
        label = 0
        return label
    elif label == 2:
        label = 1
        return label

# %% [markdown]
# From now on, and thanks to the change_bert function, 0 will correspond to neutral speech and 1 will correspond to hate speech.

# %%
twbert['BERT_label'] = twbert.BERT_label.progress_apply(change_bert)
# Out:
#   0%|          | 0/8947664 [00:00<?, ?it/s]

# %%
twbert[twbert.BERT_label == 1].shape
# Out:
# (39029, 4)

# %% [markdown]
# We have approximately 39,000 tweets labelled as hateful in our dataset.

# %% [markdown]
# #Locations

# %% [markdown]
# > Fromalizing locations

# %% [markdown]
# There is three type of location that we can find in our dataset:
#
# 1.   Correct and fairly formalized location e.g. "Washington, DC"
# 2.   Partially correct and/or unformalized location e.g. "Nashville, Tenessee"
# 3.   Locations that cannot be exploited e.g. "In my dreams"
#
# The second type of location could be retrieve via geocoding, however, geocoding is extremely slow (less than 4 iterations/second), thus it is not relevant for with our amount of data.

# %%
twbert["user_location"] = twbert["user_location"].apply(lambda x:str(x))

# %% [markdown]
# We could use the formalized locations only but this drastically reduce the size of the dataset and it could potentially lead to a lack of data, especially too little hate tweets to conduct analysis.

# %% [markdown]
# Here we are assessing the 200 most common locations. Twitter users often give their location on their own, which makes geospatial analysis really hard since the locations are given in various form and are not formalized at all.

# %%
twbert["user_location"].value_counts()[:200]
# Out:
# United States               175863
# London, England              94235
# London                       88018
# India                        86455
# USA                          76117
#                              ...
# San Jose, CA                  4649
# Delhi                         4644
# Perth, Western Australia      4633
# North East, England           4628
# Tucson, AZ                    4618
# Name: user_location, Length: 200, dtype: int64

# %% [markdown]
# While investigating the 200 most popular location we notice that most of them will be left aside. For instance, "California, USA" would be left although it is fairly formalized and could easily be kept.
#
# Let's try to keep the unrecognized American cities in the 200 most popular location.

# %%
def get_state(loc):
  flag=False
  if loc == "California, USA":
    loc = 'CA'
    flag = True
    return loc
  elif loc == "Florida, USA":
    loc = 'FL'
    flag = True
    return loc
  elif loc == "Texas, USA":
    loc = 'TX'
    flag = True
    return loc
  elif loc == "New York, USA":
    loc = 'NY'
    flag = True
    return loc
  elif loc == "New York":
    loc = 'NY'
    flag = True
    return loc
  elif loc == "New Jersey, USA":
    loc = 'NJ'
    flag = True
    return loc
  elif loc == "Los Angeles":
    loc = 'CA'
    flag = True
    return loc
  elif loc == "Texas":
    loc = 'TX'
    flag = True
    return loc
  elif loc == "New York City":
    loc = 'NY'
    flag = True
    return loc
  elif loc == "NYC":
    loc = 'NY'
    flag = True
    return loc
  elif loc == "California":
    loc = 'CA'
    flag = True
    return loc
  elif loc == "Michigan, USA":
    loc = 'MI'
    flag = True
    return loc
  elif loc == "Chicago":
    loc = 'IL'
    flag = True
    return loc
  elif loc == "Ohio, USA":
    loc = 'OH'
    flag = True
    return loc
  elif loc == "North Carolina, USA":
    loc = 'NC'
    flag = True
    return loc
  elif loc == "Virginia, USA":
    loc = 'VA'
    flag = True
    return loc
  elif loc == "Florida":
    loc = 'FL'
    flag = True
    return loc
  elif loc == "Arizona, USA":
    loc = 'AZ'
    flag = True
    return loc
  elif loc == "Massachusetts, USA":
    loc = 'MA'
    flag = True
    return loc
  elif loc == "Colorado, USA":
    loc = 'CO'
    flag = True
    return loc
  elif loc == "Georgia, USA":
    loc = 'GA'
    flag = True
    return loc
  elif loc == "Maryland, USA":
    loc = 'MD'
    flag = True
    return loc
  elif loc == "Illinois, USA":
    loc = 'IL'
    flag = True
    return loc
  elif loc == "Washington, USA":
    loc = 'WA'
    flag = True
    return loc
  elif loc == "New Jersey":
    loc = 'NJ'
    flag = True
    return loc
  elif loc == "Wisconsin, USA":
    loc = 'WI'
    flag = True
    return loc
  elif loc == "Connecticut, USA":
    loc = 'CT'
    flag = True
    return loc
  elif loc == "Michigan":
    loc = 'MI'
    flag = True
    return loc
  elif loc == "Oregon, USA":
    loc = 'OR'
    flag = True
    return loc
  elif loc == "Indiana, USA":
    loc = 'IN'
    flag = True
    return loc
  elif loc == "Tennessee, USA":
    loc = 'TN'
    flag = True
    return loc
  elif loc == "Southern California":
    loc = 'CA'
    flag = True
    return loc
  elif loc == "South Carolina, USA":
    loc = 'SC'
    flag = True
    return loc
  elif loc == "Ohio":
    loc = 'OH'
    flag = True
    return loc
  elif loc == "Colorado":
    loc = 'CO'
    flag = True
    return loc
  elif loc == "Missouri, USA":
    loc = 'MO'
    flag = True
    return loc
  elif loc == "Kentucky, USA":
    loc = 'KY'
    flag = True
    return loc
  elif loc == "North Carolina":
    loc = 'NC'
    flag = True
    return loc
  elif loc == "Arizona":
    loc = 'AZ'
    flag = True
    return loc
  else:
    return loc

# %%
twbert["user_location"]= twbert["user_location"].progress_apply(get_state)
# Out:
#   0%|          | 0/8947664 [00:00<?, ?it/s]

# %%
states = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
       'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
       'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
       'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA',
       'WI', 'WV', 'WY']

# %%
def state(val):
  flag=False
  for state in states:
    if val.endswith(" "+state):
      flag=True
      return val

  if flag==False:
    return "None"

# %%
twbert["user_location"]= twbert["user_location"].progress_apply(state)
# Out:
#   0%|          | 0/8947664 [00:00<?, ?it/s]

# %%
twbert = twbert.replace(to_replace='None', value=np.nan).dropna(subset=["user_location"])

# %%
tw["state"] = tw.user_location.apply(lambda x: x.split(",")[-1])

# %%
twbert["user_location"].value_counts()[:200]
# Out:
# Washington, DC       67712
# Los Angeles, CA      67588
# New York, NY         62422
# Chicago, IL          42162
# Atlanta, GA          30138
#                      ...
# Overland Park, KS      839
# Columbia, MO           831
# Springfield, IL        829
# Newport Beach, CA      825
# Rochester, MN          823
# Name: user_location, Length: 200, dtype: int64

# %%
print(twbert.shape)
print(twbert[twbert.BERT_label == 1].shape)
# Out:
# (1571264, 4)
# (5472, 4)

# %%
twbert.to_csv('15m_cleaned_tweets.csv')

# %%
from google.colab import files
files.download('15m_cleaned_tweets.csv')
